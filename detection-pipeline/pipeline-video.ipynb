# %%
from ultralytics import YOLO
import cv2
import os
from glob import glob

# %%
VIDEO_GLOB = os.path.join("../test", "videos", "*.mp4")
VEHICLE_CLASSES = {2, 3, 5, 7}
CONF_THRESH = 0.5

vehicle_model = YOLO("../yolov8n.pt")
plate_model = YOLO("../detection-plate/runs/detect/train/weights/best.pt")

video_glob = os.path.join("../test", "videos", "*.mp4")
video_files = sorted(glob(video_glob))
if not video_files:
    raise FileNotFoundError(f"No videos found with pattern: {video_glob}")

first_video = video_files[0]
print("Opening:", first_video)
# Out:
# Opening: ../test/videos/test-video1.mp4

# %%
def process_video(
    video_path: str,
    vehicle_model: YOLO,
    plate_model: YOLO,
    output_path: str | None = None,
):
    cap = cv2.VideoCapture(video_path)
    if not cap.isOpened():
        raise RuntimeError(f"Could not open video: {video_path}")

    writer = None
    if output_path:
        fourcc = cv2.VideoWriter_fourcc(*"mp4v")
        fps = cap.get(cv2.CAP_PROP_FPS) or 20
        w = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        h = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        writer = cv2.VideoWriter(output_path, fourcc, fps, (w, h))

    while True:
        ret, frame = cap.read()
        if not ret:
            break

        # 1) detect & track vehicles
        v_res = vehicle_model.track(frame, persist=True)[0]
        for *box, track_id, score, cls in v_res.boxes.data.tolist():
            if score < CONF_THRESH or int(cls) not in VEHICLE_CLASSES:
                continue

            x1, y1, x2, y2 = map(int, box)
            roi = frame[y1:y2, x1:x2]

            # 2) detect plates inside that vehicle ROI
            p_res = plate_model(roi)[0]
            for px1, py1, px2, py2, p_score, _ in p_res.boxes.data.tolist():
                if p_score < CONF_THRESH:
                    continue

                # map back to full frame coords
                X1, Y1 = x1 + int(px1), y1 + int(py1)
                X2, Y2 = x1 + int(px2), y1 + int(py2)
                cv2.rectangle(frame, (X1, Y1), (X2, Y2), (0, 255, 0), 2)

        # 3) draw vehicle boxes/tracks if you like
        for *box, track_id, score, cls in v_res.boxes.data.tolist():
            x1, y1, x2, y2 = map(int, box)
            cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 0, 255), 2)
            cv2.putText(
                frame,
                f"ID:{int(track_id)}",
                (x1, y1 - 5),
                cv2.FONT_HERSHEY_SIMPLEX,
                0.5,
                (0, 0, 255),
                1,
            )

        # 4) write out / show
        if writer:
            writer.write(frame)
        else:
            cv2.imshow("pipeline", frame)
            if cv2.waitKey(1) & 0xFF == ord("q"):
                break

    cap.release()
    if writer:
        writer.release()
    else:
        cv2.destroyAllWindows()

# %%
videos = sorted(glob(VIDEO_GLOB))
if not videos:
    raise FileNotFoundError(f"No .mp4s in {VIDEO_GLOB}")
first_vid = videos[0]
print("Processing:", first_vid)
# Out:
# Processing: ../test/videos/test-video1.mp4

# %%
device = "cuda" if cv2.cuda.getCudaEnabledDeviceCount() > 0 else "cpu"
out_path="./video-results"

process_video(first_vid, vehicle_model, plate_model, output_path=out_path)
print("Done ▶️", out_path)
# Out:
# [ WARN:0@760.144] global cap.cpp:645 open VIDEOIO(CV_IMAGES): raised OpenCV exception:
#
# OpenCV(4.10.0) /Users/xperience/GHA-Actions-OpenCV/_work/opencv-python/opencv-python/opencv/modules/videoio/src/cap_images.cpp:430: error: (-215:Assertion failed) !filename_pattern.empty() in function 'open'
# 0: 384x640 21 cars, 1 bus, 2 trucks, 23.4ms
# Speed: 1.5ms preprocess, 23.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 39.3ms
# Speed: 1.6ms preprocess, 39.3ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 62.0ms
# Speed: 1.1ms preprocess, 62.0ms inference, 0.4ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 1 License_Plate, 37.2ms
# Speed: 1.5ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 38.9ms
# Speed: 1.3ms preprocess, 38.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 38.2ms
# Speed: 1.5ms preprocess, 38.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 33.5ms
# Speed: 1.2ms preprocess, 33.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 192x640 (no detections), 15.2ms
# Speed: 0.6ms preprocess, 15.2ms inference, 0.2ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 384x640 (no detections), 26.4ms
# Speed: 0.9ms preprocess, 26.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 31.6ms
# Speed: 1.2ms preprocess, 31.6ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 (no detections), 38.6ms
# Speed: 1.2ms preprocess, 38.6ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x608 (no detections), 38.7ms
# Speed: 1.2ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 256x640 (no detections), 21.3ms
# Speed: 1.0ms preprocess, 21.3ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 24.8ms
# Speed: 1.3ms preprocess, 24.8ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 36.3ms
# Speed: 1.1ms preprocess, 36.3ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 35.5ms
# Speed: 1.2ms preprocess, 35.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 1 License_Plate, 37.9ms
# Speed: 1.5ms preprocess, 37.9ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 41.6ms
# Speed: 1.3ms preprocess, 41.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 2 License_Plates, 36.4ms
# Speed: 1.2ms preprocess, 36.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 192x640 (no detections), 14.3ms
# Speed: 0.8ms preprocess, 14.3ms inference, 0.1ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 384x640 (no detections), 23.3ms
# Speed: 1.1ms preprocess, 23.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 39.2ms
# Speed: 1.4ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 (no detections), 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 576x640 (no detections), 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 39.8ms
# Speed: 1.6ms preprocess, 39.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 256x640 (no detections), 40.7ms
# Speed: 0.8ms preprocess, 40.7ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 21 cars, 1 bus, 2 trucks, 25.3ms
# Speed: 1.4ms preprocess, 25.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 35.3ms
# Speed: 1.2ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 30.6ms
# Speed: 1.4ms preprocess, 30.6ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 39.2ms
# Speed: 1.3ms preprocess, 39.2ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 39.8ms
# Speed: 1.7ms preprocess, 39.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 2 License_Plates, 35.8ms
# Speed: 1.4ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 160x640 (no detections), 14.1ms
# Speed: 1.0ms preprocess, 14.1ms inference, 0.1ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 384x640 (no detections), 32.2ms
# Speed: 1.0ms preprocess, 32.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 (no detections), 31.6ms
# Speed: 1.0ms preprocess, 31.6ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 (no detections), 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 40.7ms
# Speed: 1.5ms preprocess, 40.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 29.1ms
# Speed: 1.3ms preprocess, 29.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 37.6ms
# Speed: 1.3ms preprocess, 37.6ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 33.4ms
# Speed: 1.3ms preprocess, 33.4ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 39.6ms
# Speed: 1.3ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 42.0ms
# Speed: 1.5ms preprocess, 42.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 39.2ms
# Speed: 1.5ms preprocess, 39.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 35.6ms
# Speed: 1.5ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 160x640 (no detections), 14.7ms
# Speed: 0.6ms preprocess, 14.7ms inference, 0.1ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 384x640 (no detections), 25.2ms
# Speed: 1.2ms preprocess, 25.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 38.5ms
# Speed: 1.3ms preprocess, 38.5ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 544x640 (no detections), 35.9ms
# Speed: 1.2ms preprocess, 35.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 41.7ms
# Speed: 1.7ms preprocess, 41.7ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 288x640 (no detections), 21.0ms
# Speed: 0.8ms preprocess, 21.0ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 288x640 (no detections), 22.5ms
# Speed: 0.9ms preprocess, 22.5ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 27.7ms
# Speed: 0.8ms preprocess, 27.7ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 22 cars, 1 bus, 1 truck, 26.9ms
# Speed: 1.3ms preprocess, 26.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 37.1ms
# Speed: 1.2ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 36.7ms
# Speed: 1.1ms preprocess, 36.7ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 1 License_Plate, 41.2ms
# Speed: 1.4ms preprocess, 41.2ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 42.1ms
# Speed: 1.3ms preprocess, 42.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 41.9ms
# Speed: 1.4ms preprocess, 41.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 34.7ms
# Speed: 1.3ms preprocess, 34.7ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 160x640 (no detections), 14.9ms
# Speed: 1.3ms preprocess, 14.9ms inference, 0.2ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 384x640 (no detections), 26.8ms
# Speed: 1.0ms preprocess, 26.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 38.2ms
# Speed: 1.0ms preprocess, 38.2ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 544x640 (no detections), 38.2ms
# Speed: 1.1ms preprocess, 38.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 38.1ms
# Speed: 1.1ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 42.9ms
# Speed: 1.3ms preprocess, 42.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 256x640 (no detections), 20.4ms
# Speed: 1.4ms preprocess, 20.4ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 416x640 (no detections), 27.9ms
# Speed: 1.0ms preprocess, 27.9ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 22 cars, 1 bus, 1 truck, 51.4ms
# Speed: 1.6ms preprocess, 51.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 38.3ms
# Speed: 1.2ms preprocess, 38.3ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 33.9ms
# Speed: 1.2ms preprocess, 33.9ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 39.3ms
# Speed: 1.4ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 43.4ms
# Speed: 1.3ms preprocess, 43.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 43.5ms
# Speed: 1.5ms preprocess, 43.5ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 38.1ms
# Speed: 1.6ms preprocess, 38.1ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 160x640 (no detections), 14.3ms
# Speed: 1.2ms preprocess, 14.3ms inference, 0.2ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 384x640 (no detections), 26.6ms
# Speed: 0.9ms preprocess, 26.6ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 (no detections), 38.0ms
# Speed: 1.1ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 544x640 (no detections), 37.6ms
# Speed: 1.3ms preprocess, 37.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 37.8ms
# Speed: 1.2ms preprocess, 37.8ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 42.8ms
# Speed: 1.9ms preprocess, 42.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 288x640 (no detections), 22.8ms
# Speed: 0.8ms preprocess, 22.8ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 27.4ms
# Speed: 1.0ms preprocess, 27.4ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 22 cars, 1 bus, 1 truck, 26.4ms
# Speed: 1.3ms preprocess, 26.4ms inference, 0.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 39.5ms
# Speed: 1.1ms preprocess, 39.5ms inference, 0.6ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 1 License_Plate, 37.4ms
# Speed: 1.1ms preprocess, 37.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 1 License_Plate, 38.7ms
# Speed: 1.4ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 42.7ms
# Speed: 1.5ms preprocess, 42.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 36.5ms
# Speed: 1.3ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 160x640 (no detections), 16.0ms
# Speed: 0.5ms preprocess, 16.0ms inference, 0.1ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 384x640 (no detections), 33.9ms
# Speed: 1.0ms preprocess, 33.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 41.0ms
# Speed: 1.2ms preprocess, 41.0ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 33.6ms
# Speed: 1.1ms preprocess, 33.6ms inference, 0.6ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 38.9ms
# Speed: 1.7ms preprocess, 38.9ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 43.3ms
# Speed: 1.3ms preprocess, 43.3ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 288x640 (no detections), 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 608x640 (no detections), 40.9ms
# Speed: 1.3ms preprocess, 40.9ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 22 cars, 1 bus, 2 trucks, 27.4ms
# Speed: 1.3ms preprocess, 27.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 36.2ms
# Speed: 1.4ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 36.6ms
# Speed: 1.0ms preprocess, 36.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 1 License_Plate, 40.1ms
# Speed: 1.3ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 42.8ms
# Speed: 1.8ms preprocess, 42.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 License_Plate, 39.7ms
# Speed: 1.3ms preprocess, 39.7ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 1 License_Plate, 35.8ms
# Speed: 1.7ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 128x640 (no detections), 11.9ms
# Speed: 0.9ms preprocess, 11.9ms inference, 0.1ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 384x640 (no detections), 26.0ms
# Speed: 0.9ms preprocess, 26.0ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 40.7ms
# Speed: 1.2ms preprocess, 40.7ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 37.9ms
# Speed: 1.0ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 40.6ms
# Speed: 1.6ms preprocess, 40.6ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 67.3ms
# Speed: 1.2ms preprocess, 67.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 288x640 (no detections), 21.3ms
# Speed: 1.1ms preprocess, 21.3ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 608x640 (no detections), 39.5ms
# Speed: 1.2ms preprocess, 39.5ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 27.3ms
# Speed: 1.2ms preprocess, 27.3ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 35.6ms
# Speed: 1.2ms preprocess, 35.6ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 30.5ms
# Speed: 1.1ms preprocess, 30.5ms inference, 0.6ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 38.7ms
# Speed: 1.6ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 42.7ms
# Speed: 1.7ms preprocess, 42.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 License_Plate, 43.9ms
# Speed: 1.2ms preprocess, 43.9ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 1 License_Plate, 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 128x640 (no detections), 12.4ms
# Speed: 0.5ms preprocess, 12.4ms inference, 0.2ms postprocess per image at shape (1, 3, 128, 640)
#
# 0: 384x640 (no detections), 25.7ms
# Speed: 1.0ms preprocess, 25.7ms inference, 0.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 37.4ms
# Speed: 1.2ms preprocess, 37.4ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 33.8ms
# Speed: 1.0ms preprocess, 33.8ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 39.2ms
# Speed: 1.6ms preprocess, 39.2ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 41.6ms
# Speed: 1.5ms preprocess, 41.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 288x640 (no detections), 22.0ms
# Speed: 0.6ms preprocess, 22.0ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 416x640 (no detections), 26.7ms
# Speed: 1.0ms preprocess, 26.7ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 (no detections), 24.3ms
# Speed: 1.2ms preprocess, 24.3ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 256x640 (no detections), 18.9ms
# Speed: 0.7ms preprocess, 18.9ms inference, 0.1ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 384x640 23 cars, 1 bus, 2 trucks, 29.6ms
# Speed: 1.2ms preprocess, 29.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 License_Plate, 37.8ms
# Speed: 1.3ms preprocess, 37.8ms inference, 0.4ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 (no detections), 34.1ms
# Speed: 1.2ms preprocess, 34.1ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 42.5ms
# Speed: 1.4ms preprocess, 42.5ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 43.8ms
# Speed: 1.4ms preprocess, 43.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 1 License_Plate, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 1 License_Plate, 37.2ms
# Speed: 1.2ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 (no detections), 23.9ms
# Speed: 1.1ms preprocess, 23.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 38.8ms
# Speed: 1.5ms preprocess, 38.8ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 35.2ms
# Speed: 1.2ms preprocess, 35.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 35.8ms
# Speed: 1.6ms preprocess, 35.8ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 44.6ms
# Speed: 1.2ms preprocess, 44.6ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 288x640 (no detections), 22.1ms
# Speed: 0.7ms preprocess, 22.1ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 384x640 23 cars, 1 bus, 1 truck, 28.2ms
# Speed: 1.2ms preprocess, 28.2ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 License_Plate, 36.7ms
# Speed: 1.4ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 1 License_Plate, 33.2ms
# Speed: 1.0ms preprocess, 33.2ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 40.9ms
# Speed: 1.6ms preprocess, 40.9ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 40.6ms
# Speed: 1.4ms preprocess, 40.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 42.2ms
# Speed: 1.5ms preprocess, 42.2ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 35.4ms
# Speed: 1.2ms preprocess, 35.4ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 (no detections), 41.4ms
# Speed: 0.8ms preprocess, 41.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 45.5ms
# Speed: 2.9ms preprocess, 45.5ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 35.0ms
# Speed: 1.5ms preprocess, 35.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 288x640 (no detections), 23.1ms
# Speed: 0.6ms preprocess, 23.1ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 256x640 (no detections), 20.8ms
# Speed: 0.9ms preprocess, 20.8ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 576x640 (no detections), 36.3ms
# Speed: 1.2ms preprocess, 36.3ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 384x640 23 cars, 2 buss, 27.5ms
# Speed: 1.3ms preprocess, 27.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 License_Plate, 34.6ms
# Speed: 1.2ms preprocess, 34.6ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 1 License_Plate, 30.1ms
# Speed: 1.1ms preprocess, 30.1ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 39.6ms
# Speed: 1.4ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 42.7ms
# Speed: 5.6ms preprocess, 42.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 35.8ms
# Speed: 1.3ms preprocess, 35.8ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 (no detections), 25.9ms
# Speed: 0.9ms preprocess, 25.9ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 (no detections), 38.1ms
# Speed: 1.2ms preprocess, 38.1ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 35.8ms
# Speed: 1.0ms preprocess, 35.8ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 288x640 (no detections), 20.9ms
# Speed: 1.2ms preprocess, 20.9ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 256x640 (no detections), 21.6ms
# Speed: 0.9ms preprocess, 21.6ms inference, 0.2ms postprocess per image at shape (1, 3, 256, 640)
#
# 0: 352x640 1 License_Plate, 25.0ms
# Speed: 1.0ms preprocess, 25.0ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 384x640 22 cars, 2 buss, 26.6ms
# Speed: 1.2ms preprocess, 26.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 License_Plate, 34.5ms
# Speed: 1.3ms preprocess, 34.5ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 1 License_Plate, 30.6ms
# Speed: 1.0ms preprocess, 30.6ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 39.5ms
# Speed: 1.5ms preprocess, 39.5ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 40.3ms
# Speed: 1.3ms preprocess, 40.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 41.5ms
# Speed: 1.6ms preprocess, 41.5ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 36.7ms
# Speed: 1.6ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 (no detections), 26.2ms
# Speed: 0.8ms preprocess, 26.2ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 640x640 (no detections), 41.5ms
# Speed: 1.2ms preprocess, 41.5ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 (no detections), 36.9ms
# Speed: 1.3ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 40.4ms
# Speed: 1.1ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 288x640 (no detections), 21.6ms
# Speed: 1.0ms preprocess, 21.6ms inference, 0.2ms postprocess per image at shape (1, 3, 288, 640)
#
# 0: 224x640 (no detections), 20.7ms
# Speed: 0.6ms preprocess, 20.7ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 352x640 1 License_Plate, 26.1ms
# Speed: 0.9ms preprocess, 26.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 416x640 (no detections), 27.8ms
# Speed: 1.1ms preprocess, 27.8ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 21 cars, 2 buss, 1 truck, 29.8ms
# Speed: 1.3ms preprocess, 29.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 License_Plate, 35.5ms
# Speed: 1.3ms preprocess, 35.5ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 (no detections), 31.0ms
# Speed: 1.0ms preprocess, 31.0ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 38.7ms
# Speed: 1.4ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 41.4ms
# Speed: 1.3ms preprocess, 41.4ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 40.8ms
# Speed: 1.6ms preprocess, 40.8ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 61.9ms
# Speed: 1.2ms preprocess, 61.9ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 416x640 (no detections), 25.7ms
# Speed: 0.8ms preprocess, 25.7ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 39.0ms
# Speed: 1.1ms preprocess, 39.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 (no detections), 35.3ms
# Speed: 1.0ms preprocess, 35.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 37.7ms
# Speed: 1.1ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 224x640 (no detections), 18.2ms
# Speed: 0.7ms preprocess, 18.2ms inference, 0.2ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 352x640 1 License_Plate, 24.1ms
# Speed: 0.9ms preprocess, 24.1ms inference, 0.2ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 416x640 (no detections), 27.0ms
# Speed: 0.9ms preprocess, 27.0ms inference, 0.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 384x640 22 cars, 1 bus, 1 truck, 25.5ms
# Speed: 1.3ms preprocess, 25.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 License_Plate, 35.0ms
# Speed: 1.7ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 (no detections), 33.6ms
# Speed: 0.9ms preprocess, 33.6ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 1 License_Plate, 39.3ms
# Speed: 1.5ms preprocess, 39.3ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 43.9ms
# Speed: 1.3ms preprocess, 43.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 43.7ms
# Speed: 1.4ms preprocess, 43.7ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 36.6ms
# Speed: 1.1ms preprocess, 36.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 416x640 (no detections), 28.3ms
# Speed: 0.8ms preprocess, 28.3ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 43.0ms
# Speed: 1.2ms preprocess, 43.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 (no detections), 37.0ms
# Speed: 1.1ms preprocess, 37.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 37.6ms
# Speed: 1.2ms preprocess, 37.6ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 224x640 (no detections), 18.4ms
# Speed: 0.6ms preprocess, 18.4ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 352x640 1 License_Plate, 25.6ms
# Speed: 1.4ms preprocess, 25.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 (no detections), 27.7ms
# Speed: 1.0ms preprocess, 27.7ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 22 cars, 2 buss, 1 truck, 27.6ms
# Speed: 1.3ms preprocess, 27.6ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 License_Plate, 34.7ms
# Speed: 1.1ms preprocess, 34.7ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 544x640 (no detections), 37.5ms
# Speed: 1.0ms preprocess, 37.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 1 License_Plate, 39.0ms
# Speed: 2.0ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 42.5ms
# Speed: 1.3ms preprocess, 42.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 42.9ms
# Speed: 1.5ms preprocess, 42.9ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 35.7ms
# Speed: 1.3ms preprocess, 35.7ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 416x640 (no detections), 32.5ms
# Speed: 1.1ms preprocess, 32.5ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 608x640 (no detections), 40.4ms
# Speed: 1.0ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 36.1ms
# Speed: 1.1ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 224x640 (no detections), 17.8ms
# Speed: 0.9ms preprocess, 17.8ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 352x640 1 License_Plate, 24.6ms
# Speed: 0.9ms preprocess, 24.6ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 512x640 (no detections), 32.4ms
# Speed: 1.0ms preprocess, 32.4ms inference, 0.5ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 384x640 22 cars, 2 buss, 1 truck, 26.5ms
# Speed: 1.3ms preprocess, 26.5ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 576x640 1 License_Plate, 36.2ms
# Speed: 1.1ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 544x640 (no detections), 62.0ms
# Speed: 1.0ms preprocess, 62.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 1 License_Plate, 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 42.2ms
# Speed: 1.6ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 37.2ms
# Speed: 1.2ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 416x640 (no detections), 26.7ms
# Speed: 0.8ms preprocess, 26.7ms inference, 0.1ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 43.0ms
# Speed: 1.1ms preprocess, 43.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 (no detections), 37.6ms
# Speed: 1.4ms preprocess, 37.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 224x640 (no detections), 17.3ms
# Speed: 0.6ms preprocess, 17.3ms inference, 0.1ms postprocess per image at shape (1, 3, 224, 640)
#
# 0: 352x640 1 License_Plate, 27.1ms
# Speed: 1.0ms preprocess, 27.1ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 448x640 (no detections), 28.6ms
# Speed: 1.1ms preprocess, 28.6ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 23 cars, 1 bus, 1 truck, 28.4ms
# Speed: 1.6ms preprocess, 28.4ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 35.0ms
# Speed: 1.9ms preprocess, 35.0ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 35.5ms
# Speed: 1.7ms preprocess, 35.5ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 1 License_Plate, 36.2ms
# Speed: 1.5ms preprocess, 36.2ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 40.1ms
# Speed: 1.8ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 40.3ms
# Speed: 1.4ms preprocess, 40.3ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 1 License_Plate, 39.6ms
# Speed: 1.0ms preprocess, 39.6ms inference, 0.3ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 416x640 (no detections), 26.5ms
# Speed: 0.8ms preprocess, 26.5ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 42.1ms
# Speed: 1.1ms preprocess, 42.1ms inference, 0.5ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 (no detections), 36.5ms
# Speed: 1.2ms preprocess, 36.5ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 (no detections), 37.7ms
# Speed: 1.3ms preprocess, 37.7ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 192x640 (no detections), 15.0ms
# Speed: 0.7ms preprocess, 15.0ms inference, 0.1ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 512x640 (no detections), 31.9ms
# Speed: 1.0ms preprocess, 31.9ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 352x640 (no detections), 25.9ms
# Speed: 1.0ms preprocess, 25.9ms inference, 0.1ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 512x640 (no detections), 31.2ms
# Speed: 1.2ms preprocess, 31.2ms inference, 0.1ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x192 (no detections), 17.8ms
# Speed: 0.7ms preprocess, 17.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 192)
#
# 0: 384x640 22 cars, 2 buss, 1 truck, 26.3ms
# Speed: 1.4ms preprocess, 26.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 37.8ms
# Speed: 1.5ms preprocess, 37.8ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 35.3ms
# Speed: 1.1ms preprocess, 35.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 1 License_Plate, 35.3ms
# Speed: 1.6ms preprocess, 35.3ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 42.3ms
# Speed: 1.4ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 1 License_Plate, 32.4ms
# Speed: 1.5ms preprocess, 32.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 (no detections), 27.3ms
# Speed: 0.9ms preprocess, 27.3ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 69.5ms
# Speed: 1.3ms preprocess, 69.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 (no detections), 36.7ms
# Speed: 1.2ms preprocess, 36.7ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 (no detections), 37.9ms
# Speed: 1.2ms preprocess, 37.9ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 192x640 (no detections), 15.9ms
# Speed: 1.1ms preprocess, 15.9ms inference, 0.2ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 544x640 (no detections), 36.9ms
# Speed: 1.0ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 352x640 1 License_Plate, 25.4ms
# Speed: 0.9ms preprocess, 25.4ms inference, 0.3ms postprocess per image at shape (1, 3, 352, 640)
#
# 0: 512x640 (no detections), 38.7ms
# Speed: 1.1ms preprocess, 38.7ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x224 (no detections), 19.6ms
# Speed: 0.9ms preprocess, 19.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 384x640 21 cars, 2 buss, 1 truck, 26.9ms
# Speed: 1.3ms preprocess, 26.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 37.3ms
# Speed: 1.3ms preprocess, 37.3ms inference, 0.4ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 34.9ms
# Speed: 1.1ms preprocess, 34.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 1 License_Plate, 36.9ms
# Speed: 1.4ms preprocess, 36.9ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 40.4ms
# Speed: 1.3ms preprocess, 40.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 40.5ms
# Speed: 1.6ms preprocess, 40.5ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 1 License_Plate, 30.7ms
# Speed: 1.0ms preprocess, 30.7ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 (no detections), 27.5ms
# Speed: 1.0ms preprocess, 27.5ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 640x640 (no detections), 39.6ms
# Speed: 1.2ms preprocess, 39.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 (no detections), 38.3ms
# Speed: 1.5ms preprocess, 38.3ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 (no detections), 36.9ms
# Speed: 1.5ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 192x640 (no detections), 17.0ms
# Speed: 0.9ms preprocess, 17.0ms inference, 0.1ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 544x640 (no detections), 36.2ms
# Speed: 1.1ms preprocess, 36.2ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 384x640 1 License_Plate, 25.1ms
# Speed: 0.7ms preprocess, 25.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 31.5ms
# Speed: 1.1ms preprocess, 31.5ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x224 (no detections), 18.9ms
# Speed: 1.0ms preprocess, 18.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 224)
#
# 0: 384x640 21 cars, 1 bus, 1 truck, 27.9ms
# Speed: 1.3ms preprocess, 27.9ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 38.5ms
# Speed: 1.7ms preprocess, 38.5ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 30.3ms
# Speed: 1.1ms preprocess, 30.3ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 576x640 1 License_Plate, 39.0ms
# Speed: 1.2ms preprocess, 39.0ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 40.9ms
# Speed: 1.4ms preprocess, 40.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 1 License_Plate, 32.9ms
# Speed: 1.1ms preprocess, 32.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 (no detections), 28.4ms
# Speed: 0.9ms preprocess, 28.4ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 608x640 (no detections), 39.9ms
# Speed: 1.3ms preprocess, 39.9ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 38.0ms
# Speed: 1.4ms preprocess, 38.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 (no detections), 46.7ms
# Speed: 1.5ms preprocess, 46.7ms inference, 1.0ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 56.1ms
# Speed: 4.0ms preprocess, 56.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 192x640 (no detections), 16.9ms
# Speed: 0.7ms preprocess, 16.9ms inference, 0.2ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 608x640 (no detections), 41.7ms
# Speed: 1.3ms preprocess, 41.7ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 384x640 1 License_Plate, 25.2ms
# Speed: 1.3ms preprocess, 25.2ms inference, 0.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 31.4ms
# Speed: 1.6ms preprocess, 31.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x256 (no detections), 21.8ms
# Speed: 0.7ms preprocess, 21.8ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 384x640 20 cars, 1 bus, 1 truck, 28.0ms
# Speed: 1.2ms preprocess, 28.0ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 37.2ms
# Speed: 1.8ms preprocess, 37.2ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 33.7ms
# Speed: 1.0ms preprocess, 33.7ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 576x640 1 License_Plate, 37.1ms
# Speed: 1.4ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 42.2ms
# Speed: 1.3ms preprocess, 42.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 41.2ms
# Speed: 1.5ms preprocess, 41.2ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 1 License_Plate, 30.4ms
# Speed: 1.1ms preprocess, 30.4ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 (no detections), 32.1ms
# Speed: 0.9ms preprocess, 32.1ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 576x640 (no detections), 37.3ms
# Speed: 1.2ms preprocess, 37.3ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 41.2ms
# Speed: 1.2ms preprocess, 41.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 (no detections), 41.4ms
# Speed: 1.2ms preprocess, 41.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 192x640 (no detections), 15.4ms
# Speed: 0.6ms preprocess, 15.4ms inference, 0.1ms postprocess per image at shape (1, 3, 192, 640)
#
# 0: 640x640 (no detections), 40.0ms
# Speed: 1.2ms preprocess, 40.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 26.1ms
# Speed: 1.2ms preprocess, 26.1ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 30.5ms
# Speed: 1.4ms preprocess, 30.5ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x256 (no detections), 21.3ms
# Speed: 1.3ms preprocess, 21.3ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 256)
#
# 0: 384x640 20 cars, 1 bus, 1 truck, 28.7ms
# Speed: 1.2ms preprocess, 28.7ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 37.0ms
# Speed: 1.3ms preprocess, 37.0ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 31.2ms
# Speed: 1.3ms preprocess, 31.2ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 576x640 1 License_Plate, 37.1ms
# Speed: 1.5ms preprocess, 37.1ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 44.6ms
# Speed: 1.4ms preprocess, 44.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x640 1 License_Plate, 40.0ms
# Speed: 1.5ms preprocess, 40.0ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 1 License_Plate, 33.9ms
# Speed: 1.2ms preprocess, 33.9ms inference, 0.7ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 (no detections), 28.2ms
# Speed: 1.0ms preprocess, 28.2ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 576x640 (no detections), 37.2ms
# Speed: 1.1ms preprocess, 37.2ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 (no detections), 39.8ms
# Speed: 1.8ms preprocess, 39.8ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 (no detections), 66.9ms
# Speed: 1.2ms preprocess, 66.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 160x640 (no detections), 12.2ms
# Speed: 1.0ms preprocess, 12.2ms inference, 0.5ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 384x640 (no detections), 25.4ms
# Speed: 0.9ms preprocess, 25.4ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 32.5ms
# Speed: 1.2ms preprocess, 32.5ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x288 (no detections), 22.0ms
# Speed: 1.1ms preprocess, 22.0ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 384x640 19 cars, 2 buss, 1 truck, 27.0ms
# Speed: 1.3ms preprocess, 27.0ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 36.7ms
# Speed: 1.2ms preprocess, 36.7ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 33.0ms
# Speed: 1.4ms preprocess, 33.0ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 576x640 1 License_Plate, 38.7ms
# Speed: 1.4ms preprocess, 38.7ms inference, 0.3ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 (no detections), 42.8ms
# Speed: 1.2ms preprocess, 42.8ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x640 1 License_Plate, 41.7ms
# Speed: 1.8ms preprocess, 41.7ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 2 License_Plates, 31.9ms
# Speed: 1.1ms preprocess, 31.9ms inference, 0.3ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 416x640 (no detections), 26.8ms
# Speed: 0.8ms preprocess, 26.8ms inference, 0.2ms postprocess per image at shape (1, 3, 416, 640)
#
# 0: 544x640 (no detections), 34.9ms
# Speed: 1.1ms preprocess, 34.9ms inference, 0.5ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 576x640 (no detections), 36.9ms
# Speed: 1.2ms preprocess, 36.9ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 160x640 (no detections), 14.7ms
# Speed: 0.7ms preprocess, 14.7ms inference, 0.1ms postprocess per image at shape (1, 3, 160, 640)
#
# 0: 640x640 (no detections), 41.3ms
# Speed: 1.4ms preprocess, 41.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 (no detections), 23.8ms
# Speed: 0.8ms preprocess, 23.8ms inference, 0.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 36.1ms
# Speed: 1.5ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x288 (no detections), 23.0ms
# Speed: 0.7ms preprocess, 23.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 288)
#
# 0: 640x640 (no detections), 40.8ms
# Speed: 1.2ms preprocess, 40.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 384x640 20 cars, 2 buss, 1 truck, 27.1ms
# Speed: 1.3ms preprocess, 27.1ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 608x640 1 License_Plate, 36.5ms
# Speed: 1.2ms preprocess, 36.5ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 31.6ms
# Speed: 1.1ms preprocess, 31.6ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# ...
#
# 0: 640x608 1 License_Plate, 45.9ms
# Speed: 2.0ms preprocess, 45.9ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 640x640 (no detections), 67.7ms
# Speed: 1.2ms preprocess, 67.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x352 (no detections), 34.1ms
# Speed: 0.8ms preprocess, 34.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x640 (no detections), 44.5ms
# Speed: 1.1ms preprocess, 44.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 544x640 (no detections), 37.3ms
# Speed: 1.1ms preprocess, 37.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 480x640 (no detections), 35.1ms
# Speed: 1.3ms preprocess, 35.1ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 26 cars, 2 trucks, 29.3ms
# Speed: 1.2ms preprocess, 29.3ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 512x640 (no detections), 61.0ms
# Speed: 1.6ms preprocess, 61.0ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 608x640 (no detections), 41.9ms
# Speed: 5.1ms preprocess, 41.9ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 544x640 (no detections), 37.4ms
# Speed: 0.9ms preprocess, 37.4ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x640 (no detections), 49.5ms
# Speed: 1.2ms preprocess, 49.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 (no detections), 33.2ms
# Speed: 1.2ms preprocess, 33.2ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x576 1 License_Plate, 45.0ms
# Speed: 1.5ms preprocess, 45.0ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 640x640 (no detections), 43.6ms
# Speed: 1.2ms preprocess, 43.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x352 (no detections), 55.4ms
# Speed: 2.3ms preprocess, 55.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x640 (no detections), 49.0ms
# Speed: 1.3ms preprocess, 49.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 480x640 (no detections), 34.4ms
# Speed: 1.3ms preprocess, 34.4ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 384x640 1 person, 26 cars, 2 trucks, 30.8ms
# Speed: 1.6ms preprocess, 30.8ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 69.9ms
# Speed: 3.3ms preprocess, 69.9ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 (no detections), 46.1ms
# Speed: 1.2ms preprocess, 46.1ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 41.0ms
# Speed: 1.6ms preprocess, 41.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 52.6ms
# Speed: 1.1ms preprocess, 52.6ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 (no detections), 35.7ms
# Speed: 1.2ms preprocess, 35.7ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x544 1 License_Plate, 42.4ms
# Speed: 1.4ms preprocess, 42.4ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x640 (no detections), 47.3ms
# Speed: 6.0ms preprocess, 47.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x352 (no detections), 59.4ms
# Speed: 1.9ms preprocess, 59.4ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x640 (no detections), 58.5ms
# Speed: 1.3ms preprocess, 58.5ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 448x640 (no detections), 35.1ms
# Speed: 1.2ms preprocess, 35.1ms inference, 0.3ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 26 cars, 2 trucks, 31.1ms
# Speed: 1.3ms preprocess, 31.1ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 38.4ms
# Speed: 2.8ms preprocess, 38.4ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 (no detections), 43.8ms
# Speed: 1.6ms preprocess, 43.8ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 72.7ms
# Speed: 1.1ms preprocess, 72.7ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x640 (no detections), 44.9ms
# Speed: 1.1ms preprocess, 44.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 512x640 (no detections), 36.1ms
# Speed: 1.2ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x544 1 License_Plate, 38.1ms
# Speed: 2.8ms preprocess, 38.1ms inference, 0.4ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 640x640 (no detections), 43.7ms
# Speed: 1.6ms preprocess, 43.7ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 640x384 (no detections), 34.3ms
# Speed: 2.1ms preprocess, 34.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x640 (no detections), 42.3ms
# Speed: 1.3ms preprocess, 42.3ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 (no detections), 72.8ms
# Speed: 1.2ms preprocess, 72.8ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 448x640 (no detections), 31.6ms
# Speed: 1.1ms preprocess, 31.6ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 26 cars, 2 trucks, 27.9ms
# Speed: 1.4ms preprocess, 27.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 69.3ms
# Speed: 1.3ms preprocess, 69.3ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x640 (no detections), 42.2ms
# Speed: 1.2ms preprocess, 42.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 (no detections), 39.3ms
# Speed: 1.0ms preprocess, 39.3ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 (no detections), 90.0ms
# Speed: 4.8ms preprocess, 90.0ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 480x640 (no detections), 40.0ms
# Speed: 1.1ms preprocess, 40.0ms inference, 0.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 640x544 1 License_Plate, 38.3ms
# Speed: 1.4ms preprocess, 38.3ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 544)
#
# 0: 608x640 (no detections), 68.9ms
# Speed: 1.2ms preprocess, 68.9ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x384 (no detections), 33.8ms
# Speed: 0.8ms preprocess, 33.8ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x640 (no detections), 44.0ms
# Speed: 1.2ms preprocess, 44.0ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 (no detections), 75.5ms
# Speed: 1.2ms preprocess, 75.5ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 448x640 (no detections), 31.1ms
# Speed: 1.3ms preprocess, 31.1ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 26 cars, 2 trucks, 30.4ms
# Speed: 1.3ms preprocess, 30.4ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 66.6ms
# Speed: 1.3ms preprocess, 66.6ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x640 (no detections), 44.1ms
# Speed: 2.2ms preprocess, 44.1ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 608x640 (no detections), 41.6ms
# Speed: 1.1ms preprocess, 41.6ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 608x640 (no detections), 50.4ms
# Speed: 1.1ms preprocess, 50.4ms inference, 0.8ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 37.8ms
# Speed: 1.2ms preprocess, 37.8ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x576 1 License_Plate, 40.1ms
# Speed: 1.4ms preprocess, 40.1ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 576)
#
# 0: 608x640 (no detections), 77.5ms
# Speed: 1.2ms preprocess, 77.5ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 46.2ms
# Speed: 1.9ms preprocess, 46.2ms inference, 0.6ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x384 (no detections), 35.9ms
# Speed: 0.9ms preprocess, 35.9ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 608x640 (no detections), 45.8ms
# Speed: 1.2ms preprocess, 45.8ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 448x640 (no detections), 32.8ms
# Speed: 1.3ms preprocess, 32.8ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 25 cars, 3 trucks, 42.9ms
# Speed: 1.4ms preprocess, 42.9ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 36.1ms
# Speed: 1.4ms preprocess, 36.1ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 640x640 (no detections), 77.2ms
# Speed: 1.3ms preprocess, 77.2ms inference, 0.2ms postprocess per image at shape (1, 3, 640, 640)
#
# 0: 576x640 (no detections), 48.4ms
# Speed: 1.2ms preprocess, 48.4ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 576x640 (no detections), 43.9ms
# Speed: 1.1ms preprocess, 43.9ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 512x640 (no detections), 62.5ms
# Speed: 1.3ms preprocess, 62.5ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x608 1 License_Plate, 51.2ms
# Speed: 3.5ms preprocess, 51.2ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 608x640 (no detections), 46.9ms
# Speed: 1.2ms preprocess, 46.9ms inference, 0.3ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 640x416 (no detections), 39.0ms
# Speed: 0.9ms preprocess, 39.0ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 448x640 (no detections), 53.5ms
# Speed: 3.6ms preprocess, 53.5ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
#
# 0: 384x640 1 person, 25 cars, 1 bus, 3 trucks, 31.7ms
# Speed: 1.7ms preprocess, 31.7ms inference, 0.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 544x640 (no detections), 35.0ms
# Speed: 1.3ms preprocess, 35.0ms inference, 0.2ms postprocess per image at shape (1, 3, 544, 640)
#
# 0: 608x640 (no detections), 78.6ms
# Speed: 1.7ms preprocess, 78.6ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 576x640 (no detections), 40.0ms
# Speed: 1.4ms preprocess, 40.0ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 608x640 (no detections), 45.7ms
# Speed: 1.0ms preprocess, 45.7ms inference, 0.2ms postprocess per image at shape (1, 3, 608, 640)
#
# 0: 512x640 (no detections), 32.9ms
# Speed: 1.2ms preprocess, 32.9ms inference, 0.2ms postprocess per image at shape (1, 3, 512, 640)
#
# 0: 640x608 1 License_Plate, 42.3ms
# Speed: 1.8ms preprocess, 42.3ms inference, 0.3ms postprocess per image at shape (1, 3, 640, 608)
#
# 0: 576x640 (no detections), 45.7ms
# Speed: 1.1ms preprocess, 45.7ms inference, 0.2ms postprocess per image at shape (1, 3, 576, 640)
#
# 0: 640x416 (no detections), 25.9ms
# Speed: 0.8ms preprocess, 25.9ms inference, 0.1ms postprocess per image at shape (1, 3, 640, 416)
#
# 0: 448x640 (no detections), 34.1ms
# Speed: 1.4ms preprocess, 34.1ms inference, 0.2ms postprocess per image at shape (1, 3, 448, 640)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 4
#       1 device = "cuda" if cv2.cuda.getCudaEnabledDeviceCount() > 0 else "cpu"
#       2 out_path="./video-results"
# ----> 4 process_video(first_vid, vehicle_model, plate_model, output_path=out_path)
#       5 print("Done ▶️", out_path)
#
# Cell In[20], line 25, in process_video(video_path, vehicle_model, plate_model, output_path)
#      22     break
#      24 # 1) detect & track vehicles
# ---> 25 v_res = vehicle_model.track(frame, persist=True)[0]
#      26 for *box, track_id, score, cls in v_res.boxes.data.tolist():
#      27     if score < CONF_THRESH or int(cls) not in VEHICLE_CLASSES:
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/model.py:599, in Model.track(self, source, stream, persist, **kwargs)
#     597 kwargs["batch"] = kwargs.get("batch") or 1  # batch-size 1 for tracking in videos
#     598 kwargs["mode"] = "track"
# --> 599 return self.predict(source=source, stream=stream, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/model.py:555, in Model.predict(self, source, stream, predictor, **kwargs)
#     553 if prompts and hasattr(self.predictor, "set_prompts"):  # for SAM-type models
#     554     self.predictor.set_prompts(prompts)
# --> 555 return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/predictor.py:227, in BasePredictor.__call__(self, source, model, stream, *args, **kwargs)
#     225     return self.stream_inference(source, model, *args, **kwargs)
#     226 else:
# --> 227     return list(self.stream_inference(source, model, *args, **kwargs))
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/torch/utils/_contextlib.py:36, in _wrap_generator.<locals>.generator_context(*args, **kwargs)
#      33 try:
#      34     # Issuing `None` to a generator fires it up
#      35     with ctx_factory():
# ---> 36         response = gen.send(None)
#      38     while True:
#      39         try:
#      40             # Forward the response to our caller and get its next request
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/predictor.py:338, in BasePredictor.stream_inference(self, source, model, *args, **kwargs)
#     336 with profilers[2]:
#     337     self.results = self.postprocess(preds, im, im0s)
# --> 338 self.run_callbacks("on_predict_postprocess_end")
#     340 # Visualize, save, write results
#     341 n = len(im0s)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/engine/predictor.py:500, in BasePredictor.run_callbacks(self, event)
#     498 """Run all registered callbacks for a specific event."""
#     499 for callback in self.callbacks.get(event, []):
# --> 500     callback(self)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/trackers/track.py:97, in on_predict_postprocess_end(predictor, persist)
#      95 if len(det) == 0:
#      96     continue
# ---> 97 tracks = tracker.update(det, result.orig_img, getattr(result, "feats", None))
#      98 if len(tracks) == 0:
#      99     continue
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/trackers/byte_tracker.py:339, in BYTETracker.update(self, results, img, feats)
#     336 if hasattr(self, "gmc") and img is not None:
#     337     # use try-except here to bypass errors from gmc module
#     338     try:
# --> 339         warp = self.gmc.apply(img, dets)
#     340     except Exception:
#     341         warp = np.eye(2, 3)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/trackers/utils/gmc.py:115, in GMC.apply(self, raw_frame, detections)
#     113     return self.apply_ecc(raw_frame)
#     114 elif self.method == "sparseOptFlow":
# --> 115     return self.apply_sparseoptflow(raw_frame)
#     116 else:
#     117     return np.eye(2, 3)
#
# File /Library/Frameworks/Python.framework/Versions/3.12/lib/python3.12/site-packages/ultralytics/trackers/utils/gmc.py:295, in GMC.apply_sparseoptflow(self, raw_frame)
#     278 """
#     279 Apply Sparse Optical Flow method to a raw frame.
#     280
#    (...)
#     292      [0. 1. 0.]]
#     293 """
#     294 height, width, c = raw_frame.shape
# --> 295 frame = cv2.cvtColor(raw_frame, cv2.COLOR_BGR2GRAY) if c == 3 else raw_frame
#     296 H = np.eye(2, 3)
#     298 # Downscale image for computational efficiency
#
# KeyboardInterrupt:
